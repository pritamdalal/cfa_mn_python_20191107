# %% [markdown]
# # Tutorial 10 - Joining `DataFrames`

# %% [markdown]
# In data analysis you will often need to combine the data from two or more `DataFrames`.
#
# This is known as *joining*, which is a term that is borrowed from the world of SQL.
#
# The effect of joining is similar to the lookup functions in Excel.

# %% [markdown]
# ## Loading Packages

# %% [markdown]
# Let's load the packages we will need for this tutorial.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading-In Data

# %% [markdown]
# The data set we are going to use is a list of ETFs that have weekly expiring options.  What does that mean?  Most stocks or ETFs have exchange traded options that expire every month, and at any given time the monthly expiring options go out about a year.  The most liquid underlyings have actually have options that expire every week; these weekly expiring options go out about 6-8 weeks.
#
# This is a list that is published by the CBOE and it consists of all the ETFs that have weekly options trading.

# %%
df_weekly = pd.read_csv("../data/weekly_etf.csv")
df_weekly.head()
# Out:
#   ticker                                             name
# 0    AMJ                  JP Morgan Alerian MLP Index ETN
# 1   AMLP                                  Alerian MLP ETF
# 2   ASHR     Xtrackers Harvest CSI 300 China A-Shares ETF
# 3    DIA                  SPDR Dow Jones Ind Av ETF Trust
# 4   DUST  Direxion Daily Gold Miners Index Bear 3X Shares

# %% [markdown]
# The next data set that we are going to load is a comprehensive list of all ETFs that are trading in the market.

# %%
df_etf = pd.read_csv("../data/etf_list.csv")
df_etf.head()
# Out:
#   symbol                             name                        issuer  \
# 0    SPY           SPDR S&P 500 ETF Trust  State Street Global Advisors
# 1    IVV         iShares Core S&P 500 ETF                     BlackRock
# 2    VTI  Vanguard Total Stock Market ETF                      Vanguard
# 3    VOO             Vanguard S&P 500 ETF                      Vanguard
# 4    EFA            iShares MSCI EAFE ETF                     BlackRock
#
#   expense_ratio       aum spread  \
# 0         0.09%  $275.42B  0.00%
# 1         0.04%  $155.86B  0.01%
# 2         0.04%  $103.58B  0.01%
# 3         0.04%   $96.91B  0.01%
# 4         0.32%   $72.12B  0.01%
#
#                                             segment
# 0                          Equity: U.S. - Large Cap
# 1                          Equity: U.S. - Large Cap
# 2                       Equity: U.S. - Total Market
# 3                          Equity: U.S. - Large Cap
# 4  Equity: Developed Markets Ex-U.S. - Total Market

# %% [markdown]
# **Motivation:** Notice that `df_etf` has a `segment` column which `df_weekly` does not.  This `segment` column contains asset-class information that could be useful for categorizing the weekly ETFs.
#
# **Objective:** we want to get the `segment` column into `df_weekly`.

# %% [markdown]
# There are a couple of ways of accomplishing this in `pandas` and both of them involve the `pd.merge()` method:
#
# 1. *inner-joins*
#
# 2. *left/right-joins* (sometimes called *outer joins*)

# %% [markdown]
# ## Inner-Join

# %% [markdown]
# As with many of the basic operations in data analysis, it's easiest to understand inner-joins by digging into an example.
#
# Here is the line of code that accomplishes most of the work that we want done:

# %%
pd.merge(df_weekly, df_etf, how='inner', left_on='ticker', right_on='symbol')
# Out:
#    ticker                                            name_x symbol  \
# 0     AMJ                   JP Morgan Alerian MLP Index ETN    AMJ
# 1    AMLP                                   Alerian MLP ETF   AMLP
# 2    ASHR      Xtrackers Harvest CSI 300 China A-Shares ETF   ASHR
# 3     DIA                   SPDR Dow Jones Ind Av ETF Trust    DIA
# 4    DUST   Direxion Daily Gold Miners Index Bear 3X Shares   DUST
# 5     DXJ                         Wisdom JPN Hedged EQ Fund    DXJ
# 6     EEM               iShares MSCI Emerging Markets Index    EEM
# 7     EFA                      iShares MSCI EAFE Index Fund    EFA
# 8     EPI                   Wisdom Tree India Earnings Fund    EPI
# 9     EWG                          iShares MSCI Germany ETF    EWG
# 10    EWI                            iShares MSCI Italy ETF    EWI
# 11    EWJ                     iShares MSCI Japan Index Fund    EWJ
# 12    EWU                   iShares MSCI United Kingdom ETF    EWU
# 13    EWW                    iShares MSCI Mexico Capped ETF    EWW
# 14    EWY           iShares MSCI South Korea Index Fund ETF    EWY
# 15    EWZ                    iShares MSCI Brazil Capped ETF    EWZ
# 16    FEZ                            SPDR Euro Stoxx 50 ETF    FEZ
# 17    FXE                        Currency Shares Euro Trust    FXE
# 18    FXI              Ishares FTSE/Xinhua China Index Fund    FXI
# 19    FXY                Currency Shares Japanese Yen Trust    FXY
# 20    GDX                    VanEck Vectors Gold Miners ETF    GDX
# 21   GDXJ             VanEck Vectors Junior Gold Miners ETF   GDXJ
# 22    GLD                                   SPDR Gold Trust    GLD
# 23   GREK                       GLOBAL X FTSE GREECE 20 ETF   GREK
# 24   HEDJ                        WisdomTree Intl. HDGD EQTY   HEDJ
# 25    HYG            iShares iBoxx High Yield Corp. Bd. ETF    HYG
# 26    IAU                                iShares Gold Trust    IAU
# 27    IBB                  iShares Nasdaq Biotechnology ETF    IBB
# 28    IEF               ISHARES 7-10 YEAR TREASURY BOND ETF    IEF
# 29    ITB                  iShares US Home Construction ETF    ITB
# ..    ...                                               ...    ...
# 36    RSX                         VanEck Vectors Russia ETF    RSX
# 37    SCO             ProShares UltraShort DJ-AIG Crude Oil    SCO
# 38    SDS                     Proshares Ultra Short S&P 500    SDS
# 39    SHY                iShares 1-3 Year Treasury Bond ETF    SHY
# 40    SLV                              iShares Silver Trust    SLV
# 41    SMH                  VanEck Vectors Semiconductor ETF    SMH
# 42    SPY                                  SPDR S&P 500 ETF    SPY
# 43    SSO                    Pro Shares Trust Ultra S&P 500    SSO
# 44    TBT    Proshares Ultrashort Barclays 20+ Yr. Treasury    TBT
# 45    TLT  iShares Trust Barclays 20+ Yr. Treasury Bond Fd.    TLT
# 46   TQQQ                            Proshares UltraPro QQQ   TQQQ
# 47    UCO                  Proshares Ultra DJ-AIG Crude Oil    UCO
# 48    UNG                    United States Natural Gas Fund    UNG
# 49   UPRO                         Proshares UltrPro S&P 500   UPRO
# 50    USO                            United States Oil Fund    USO
# 51    UUP                 Power Shares DB US Dollar Bullish    UUP
# 52    XBI                              SPDR (R) Biotech ETF    XBI
# 53    XHB                         SPDR S&P Homebuilders ETF    XHB
# 54    XLB                      Materials Select Sector SPDR    XLB
# 55    XLE                                Energy Sector SPDR    XLE
# 56    XLF                      Financial Select Sector SPDR    XLF
# 57    XLI                            Industrial Sector SPDR    XLI
# 58    XLK                            Technology Sector SPDR    XLK
# 59    XLP                      Consumer Staples Sector SPDR    XLP
# 60    XLU                             Utilities Sector SPDR    XLU
# 61    XLV                    HEALTH CARE SELECT SECTOR SPDR    XLV
# 62    XLY         Consumer Discretionary Select Sector SPDR    XLY
# 63    XME                      SPDR S&P Metals & Mining ETF    XME
# 64    XOP          P Oil & Gas Exploration & Production ETF    XOP
# 65    XRT   SPDR S&P Oil & Gas Exploration & Production ETF    XRT
#
#                                              name_y  \
# 0                 J.P. Morgan Alerian MLP Index ETN
# 1                                   Alerian MLP ETF
# 2      Xtrackers Harvest CSI 300 China A-Shares ETF
# 3       SPDR Dow Jones Industrial Average ETF Trust
# 4   Direxion Daily Gold Miners Index Bear 3x Shares
# 5               WisdomTree Japan Hedged Equity Fund
# 6                 iShares MSCI Emerging Markets ETF
# 7                             iShares MSCI EAFE ETF
# 8                    WisdomTree India Earnings Fund
# 9                          iShares MSCI Germany ETF
# 10                           iShares MSCI Italy ETF
# 11                           iShares MSCI Japan ETF
# 12                  iShares MSCI United Kingdom ETF
# 13                          iShares MSCI Mexico ETF
# 14                     iShares MSCI South Korea ETF
# 15                          iShares MSCI Brazil ETF
# 16                           SPDR Euro STOXX 50 ETF
# 17                Invesco CurrencyShares Euro Trust
# 18                      iShares China Large-Cap ETF
# 19        Invesco CurrencyShares Japanese Yen Trust
# 20                   VanEck Vectors Gold Miners ETF
# 21            VanEck Vectors Junior Gold Miners ETF
# 22                                  SPDR Gold Trust
# 23                         Global X MSCI Greece ETF
# 24             WisdomTree Europe Hedged Equity Fund
# 25  iShares iBoxx USD High Yield Corporate Bond ETF
# 26                               iShares Gold Trust
# 27                 iShares NASDAQ Biotechnology ETF
# 28              iShares 7-10 Year Treasury Bond ETF
# 29               iShares U.S. Home Construction ETF
# ..                                              ...
# 36                        VanEck Vectors Russia ETF
# 37         ProShares UltraShort Bloomberg Crude Oil
# 38                      ProShares UltraShort S&P500
# 39               iShares 1-3 Year Treasury Bond ETF
# 40                             iShares Silver Trust
# 41                 VanEck Vectors Semiconductor ETF
# 42                           SPDR S&P 500 ETF Trust
# 43                          ProShares Ultra S&P 500
# 44           ProShares UltraShort 20+ Year Treasury
# 45               iShares 20+ Year Treasury Bond ETF
# 46                           ProShares UltraPro QQQ
# 47              ProShares Ultra Bloomberg Crude Oil
# 48                United States Natural Gas Fund LP
# 49                        ProShares UltraPro S&P500
# 50                        United States Oil Fund LP
# 51        Invesco DB U.S. Dollar Index Bullish Fund
# 52                             SPDR S&P BIOTECH ETF
# 53                        SPDR S&P Homebuilders ETF
# 54                Materials Select Sector SPDR Fund
# 55                   Energy Select Sector SPDR Fund
# 56                Financial Select Sector SPDR Fund
# 57               Industrial Select Sector SPDR Fund
# 58               Technology Select Sector SPDR Fund
# 59         Consumer Staples Select Sector SPDR Fund
# 60                Utilities Select Sector SPDR Fund
# 61              Health Care Select Sector SPDR Fund
# 62   Consumer Discretionary Select Sector SPDR Fund
# 63                     SPDR S&P Metals & Mining ETF
# 64  SPDR S&P Oil & Gas Exploration & Production ETF
# 65                              SPDR S&P Retail ETF
#
#                             issuer expense_ratio       aum spread  \
# 0                         JPMorgan         0.85%    $3.45B  0.04%
# 1                             ALPS         0.85%   $10.64B  0.10%
# 2                    Deutsche Bank         0.65%  $630.14M  0.04%
# 3     State Street Global Advisors         0.17%   $21.70B  0.01%
# 4                         Direxion         1.08%  $122.21M  0.06%
# 5                       WisdomTree         0.48%    $5.87B  0.02%
# 6                        BlackRock         0.69%   $31.82B  0.02%
# 7                        BlackRock         0.32%   $72.12B  0.01%
# 8                       WisdomTree         0.84%    $1.57B  0.04%
# 9                        BlackRock         0.49%    $3.44B  0.03%
# 10                       BlackRock         0.49%  $452.61M  0.03%
# 11                       BlackRock         0.49%   $17.39B  0.02%
# 12                       BlackRock         0.49%    $2.06B  0.03%
# 13                       BlackRock         0.49%    $1.26B  0.02%
# 14                       BlackRock         0.62%    $3.84B  0.02%
# 15                       BlackRock         0.62%    $6.88B  0.03%
# 16    State Street Global Advisors         0.29%    $3.56B  0.03%
# 17                         Invesco         0.40%  $250.31M  0.01%
# 18                       BlackRock         0.74%    $4.05B  0.02%
# 19                         Invesco         0.40%  $125.03M  0.02%
# 20                          VanEck         0.53%    $8.82B  0.05%
# 21                          VanEck         0.54%    $4.90B  0.03%
# 22    State Street Global Advisors         0.40%   $30.57B  0.01%
# 23  Mirae Asset Global Investments         0.59%  $388.17M  0.11%
# 24                      WisdomTree         0.58%    $5.55B  0.02%
# 25                       BlackRock         0.49%   $16.35B  0.01%
# 26                       BlackRock         0.25%   $10.18B  0.08%
# 27                       BlackRock         0.47%    $9.28B  0.03%
# 28                       BlackRock         0.15%    $9.10B  0.01%
# 29                       BlackRock         0.43%    $1.09B  0.03%
# ..                             ...           ...       ...    ...
# 36                          VanEck         0.67%    $1.66B  0.05%
# 37                       ProShares         1.25%  $168.01M  0.06%
# 38                       ProShares         0.89%  $842.62M  0.03%
# 39                       BlackRock         0.15%   $13.30B  0.01%
# 40                       BlackRock         0.50%    $5.04B  0.07%
# 41                          VanEck         0.35%    $1.30B  0.01%
# 42    State Street Global Advisors         0.09%  $275.42B  0.00%
# 43                       ProShares         0.90%    $2.59B  0.02%
# 44                       ProShares         0.90%    $1.76B  0.03%
# 45                       BlackRock         0.15%    $7.67B  0.01%
# 46                       ProShares         0.95%    $3.73B  0.02%
# 47                       ProShares         1.27%  $411.81M  0.04%
# 48              US Commodity Funds         1.29%  $331.18M  0.04%
# 49                       ProShares         0.95%    $1.47B  0.03%
# 50              US Commodity Funds         0.84%    $1.76B  0.07%
# 51                         Invesco         0.79%  $507.86M  0.04%
# 52    State Street Global Advisors         0.35%    $5.40B  0.03%
# 53    State Street Global Advisors         0.35%  $892.25M  0.03%
# 54    State Street Global Advisors         0.13%    $4.70B  0.02%
# 55    State Street Global Advisors         0.13%   $18.64B  0.01%
# 56    State Street Global Advisors         0.13%   $32.71B  0.04%
# 57    State Street Global Advisors         0.13%   $13.00B  0.01%
# 58    State Street Global Advisors         0.13%   $23.08B  0.01%
# 59    State Street Global Advisors         0.13%    $9.15B  0.02%
# 60    State Street Global Advisors         0.13%    $7.81B  0.02%
# 61    State Street Global Advisors         0.13%   $17.49B  0.01%
# 62    State Street Global Advisors         0.13%   $14.35B  0.01%
# 63    State Street Global Advisors         0.35%  $879.10M  0.03%
# 64    State Street Global Advisors         0.35%    $3.06B  0.02%
# 65    State Street Global Advisors         0.35%  $704.67M  0.02%
#
#                                               segment
# 0                                   Equity: U.S. MLPs
# 1                                   Equity: U.S. MLPs
# 2                        Equity: China - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                  Inverse Equity: Global Gold Miners
# 5                        Equity: Japan - Total Market
# 6             Equity: Emerging Markets - Total Market
# 7    Equity: Developed Markets Ex-U.S. - Total Market
# 8                        Equity: India - Total Market
# 9                      Equity: Germany - Total Market
# 10                       Equity: Italy - Total Market
# 11                       Equity: Japan - Total Market
# 12                        Equity: U.K. - Total Market
# 13                      Equity: Mexico - Total Market
# 14                 Equity: South Korea - Total Market
# 15                      Equity: Brazil - Total Market
# 16               Equity: Developed Europe - Large Cap
# 17                                     Currency: Euro
# 18                          Equity: China - Large Cap
# 19                             Currency: Japanese Yen
# 20                         Equity: Global Gold Miners
# 21                         Equity: Global Gold Miners
# 22                  Commodities: Precious Metals Gold
# 23                      Equity: Greece - Total Market
# 24            Equity: Developed Europe - Total Market
# 25          Fixed Income: U.S. - Corporate High Yield
# 26                  Commodities: Precious Metals Gold
# 27                               Equity: U.S. Biotech
# 28  Fixed Income: U.S. Government Treasury Interme...
# 29                          Equity: U.S. Homebuilding
# ..                                                ...
# 36                      Equity: Russia - Total Market
# 37              Inverse Commodities: Energy Crude Oil
# 38                   Inverse Equity: U.S. - Large Cap
# 39  Fixed Income: U.S. Government Treasury Short-Term
# 40                Commodities: Precious Metals Silver
# 41                      Equity: Global Semiconductors
# 42                           Equity: U.S. - Large Cap
# 43                 Leveraged Equity: U.S. - Large Cap
# 44  Inverse Fixed Income: U.S. Government Treasury...
# 45   Fixed Income: U.S. Government Treasury Long-Term
# 46                 Leveraged Equity: U.S. - Large Cap
# 47            Leveraged Commodities: Energy Crude Oil
# 48                    Commodities: Energy Natural Gas
# 49                 Leveraged Equity: U.S. - Large Cap
# 50                      Commodities: Energy Crude Oil
# 51            Inverse Currency: Basket - Global Ex-US
# 52                               Equity: U.S. Biotech
# 53                          Equity: U.S. Homebuilding
# 54                       Equity: U.S. Basic Materials
# 55                                Equity: U.S. Energy
# 56                            Equity: U.S. Financials
# 57                           Equity: U.S. Industrials
# 58                            Equity: U.S. Technology
# 59                Equity: U.S. Consumer Non-cyclicals
# 60                             Equity: U.S. Utilities
# 61                           Equity: U.S. Health Care
# 62                    Equity: U.S. Consumer Cyclicals
# 63                       Equity: U.S. Metals & Mining
# 64    Equity: U.S. Oil & Gas Exploration & Production
# 65                                Equity: U.S. Retail
#
# [66 rows x 9 columns]

# %% [markdown]
# Observations on the syntax:
#
# 1. The first two arguments of `pd.merge()` are the two `DataFrames` we want to join together.  The first `DataFrame` is the *left* `DataFrame` and the second on is the *right* `DataFrame`.
#
# 2. The `how` argument defines the type of join.
#
# 3. `left_on` is the column in the left table that will be used for matching, `right_on` is the column in the right table that will be used for matching.

# %% [markdown]
# Observations on output:
#
# 1. The output is basically each of the two tables smashed together, however only the rows with matching ticker/symbol are retained in the output.  All columns of both tables are included.
#
# 2. `df_weekly` had 67 rows in it, and `df_etf` had 2,160 row in it.  The `DataFrame` that results from `pd.merge()` has 66 rows in it.
#
# 3. Notice that both `df_weekly` and `df_etf` have a column called `name`.  In the joined dataframe, suffixes of `_x` and `_y` have been added to the column names to make them unambiguous.

# %% [markdown]
# Let's do a little clean up of our `DataFrame` so that it's just the information that we wanted: `df_weekly` with the `segment` column added to it.

# %%
# keeping only the columns that we want
# assigning the joined result to a variable called df_joined  
df_joined = \
    pd.merge(df_weekly, df_etf, how='inner', left_on='ticker', right_on='symbol') \
    [['ticker', 'name_x', 'segment']]

# renaming the 'name' column
df_joined.rename(columns={'name_x':'name'}, inplace=True)

# let's look at our result
df_joined.head()
# Out:
#   ticker                                             name  \
# 0    AMJ                  JP Morgan Alerian MLP Index ETN
# 1   AMLP                                  Alerian MLP ETF
# 2   ASHR     Xtrackers Harvest CSI 300 China A-Shares ETF
# 3    DIA                  SPDR Dow Jones Ind Av ETF Trust
# 4   DUST  Direxion Daily Gold Miners Index Bear 3X Shares
#
#                               segment
# 0                   Equity: U.S. MLPs
# 1                   Equity: U.S. MLPs
# 2        Equity: China - Total Market
# 3            Equity: U.S. - Large Cap
# 4  Inverse Equity: Global Gold Miners

# %% [markdown]
# ## Left-Join

# %% [markdown]
# Notice that in the inner-join example from the previous section, the original list of ETFs with weekly options (`df_weekly`) had 67 rows, but the joined table with the `segment` column added only has 66 rows.

# %%
print(df_weekly.shape)
print(df_joined.shape)
# Out:
# (67, 2)
# (66, 3)

# %% [markdown]
# So what happened?  This means that one of the `tickers` from `df_weekly` had no matching `symbol` in `df_eft`.
#
# Inner-joins, by design, are only intended to retain rows that have matches in both tables.  This may or may not be the desired behavior you are looking for.
#
# Let's say that instead we wanted to keep *ALL* the rows in the left `DataFrame`, `df_weekly`, irrespective of whether there is a match in the right `DataFrame`.
#
# This is precisely what a *left-join* is.  The syntax is the exact same as before except for the `how` argument is set to `inner`.

# %%
pd.merge(df_weekly, df_etf, how='left', left_on='ticker', right_on='symbol')
# Out:
#    ticker                                            name_x symbol  \
# 0     AMJ                   JP Morgan Alerian MLP Index ETN    AMJ
# 1    AMLP                                   Alerian MLP ETF   AMLP
# 2    ASHR      Xtrackers Harvest CSI 300 China A-Shares ETF   ASHR
# 3     DIA                   SPDR Dow Jones Ind Av ETF Trust    DIA
# 4    DUST   Direxion Daily Gold Miners Index Bear 3X Shares   DUST
# 5     DXJ                         Wisdom JPN Hedged EQ Fund    DXJ
# 6     EEM               iShares MSCI Emerging Markets Index    EEM
# 7     EFA                      iShares MSCI EAFE Index Fund    EFA
# 8     EPI                   Wisdom Tree India Earnings Fund    EPI
# 9     EWG                          iShares MSCI Germany ETF    EWG
# 10    EWI                            iShares MSCI Italy ETF    EWI
# 11    EWJ                     iShares MSCI Japan Index Fund    EWJ
# 12    EWU                   iShares MSCI United Kingdom ETF    EWU
# 13    EWW                    iShares MSCI Mexico Capped ETF    EWW
# 14    EWY           iShares MSCI South Korea Index Fund ETF    EWY
# 15    EWZ                    iShares MSCI Brazil Capped ETF    EWZ
# 16    FEZ                            SPDR Euro Stoxx 50 ETF    FEZ
# 17    FTK                             FLOTEK INDUSTRIES INC    NaN
# 18    FXE                        Currency Shares Euro Trust    FXE
# 19    FXI              Ishares FTSE/Xinhua China Index Fund    FXI
# 20    FXY                Currency Shares Japanese Yen Trust    FXY
# 21    GDX                    VanEck Vectors Gold Miners ETF    GDX
# 22   GDXJ             VanEck Vectors Junior Gold Miners ETF   GDXJ
# 23    GLD                                   SPDR Gold Trust    GLD
# 24   GREK                       GLOBAL X FTSE GREECE 20 ETF   GREK
# 25   HEDJ                        WisdomTree Intl. HDGD EQTY   HEDJ
# 26    HYG            iShares iBoxx High Yield Corp. Bd. ETF    HYG
# 27    IAU                                iShares Gold Trust    IAU
# 28    IBB                  iShares Nasdaq Biotechnology ETF    IBB
# 29    IEF               ISHARES 7-10 YEAR TREASURY BOND ETF    IEF
# ..    ...                                               ...    ...
# 37    RSX                         VanEck Vectors Russia ETF    RSX
# 38    SCO             ProShares UltraShort DJ-AIG Crude Oil    SCO
# 39    SDS                     Proshares Ultra Short S&P 500    SDS
# 40    SHY                iShares 1-3 Year Treasury Bond ETF    SHY
# 41    SLV                              iShares Silver Trust    SLV
# 42    SMH                  VanEck Vectors Semiconductor ETF    SMH
# 43    SPY                                  SPDR S&P 500 ETF    SPY
# 44    SSO                    Pro Shares Trust Ultra S&P 500    SSO
# 45    TBT    Proshares Ultrashort Barclays 20+ Yr. Treasury    TBT
# 46    TLT  iShares Trust Barclays 20+ Yr. Treasury Bond Fd.    TLT
# 47   TQQQ                            Proshares UltraPro QQQ   TQQQ
# 48    UCO                  Proshares Ultra DJ-AIG Crude Oil    UCO
# 49    UNG                    United States Natural Gas Fund    UNG
# 50   UPRO                         Proshares UltrPro S&P 500   UPRO
# 51    USO                            United States Oil Fund    USO
# 52    UUP                 Power Shares DB US Dollar Bullish    UUP
# 53    XBI                              SPDR (R) Biotech ETF    XBI
# 54    XHB                         SPDR S&P Homebuilders ETF    XHB
# 55    XLB                      Materials Select Sector SPDR    XLB
# 56    XLE                                Energy Sector SPDR    XLE
# 57    XLF                      Financial Select Sector SPDR    XLF
# 58    XLI                            Industrial Sector SPDR    XLI
# 59    XLK                            Technology Sector SPDR    XLK
# 60    XLP                      Consumer Staples Sector SPDR    XLP
# 61    XLU                             Utilities Sector SPDR    XLU
# 62    XLV                    HEALTH CARE SELECT SECTOR SPDR    XLV
# 63    XLY         Consumer Discretionary Select Sector SPDR    XLY
# 64    XME                      SPDR S&P Metals & Mining ETF    XME
# 65    XOP          P Oil & Gas Exploration & Production ETF    XOP
# 66    XRT   SPDR S&P Oil & Gas Exploration & Production ETF    XRT
#
#                                              name_y  \
# 0                 J.P. Morgan Alerian MLP Index ETN
# 1                                   Alerian MLP ETF
# 2      Xtrackers Harvest CSI 300 China A-Shares ETF
# 3       SPDR Dow Jones Industrial Average ETF Trust
# 4   Direxion Daily Gold Miners Index Bear 3x Shares
# 5               WisdomTree Japan Hedged Equity Fund
# 6                 iShares MSCI Emerging Markets ETF
# 7                             iShares MSCI EAFE ETF
# 8                    WisdomTree India Earnings Fund
# 9                          iShares MSCI Germany ETF
# 10                           iShares MSCI Italy ETF
# 11                           iShares MSCI Japan ETF
# 12                  iShares MSCI United Kingdom ETF
# 13                          iShares MSCI Mexico ETF
# 14                     iShares MSCI South Korea ETF
# 15                          iShares MSCI Brazil ETF
# 16                           SPDR Euro STOXX 50 ETF
# 17                                              NaN
# 18                Invesco CurrencyShares Euro Trust
# 19                      iShares China Large-Cap ETF
# 20        Invesco CurrencyShares Japanese Yen Trust
# 21                   VanEck Vectors Gold Miners ETF
# 22            VanEck Vectors Junior Gold Miners ETF
# 23                                  SPDR Gold Trust
# 24                         Global X MSCI Greece ETF
# 25             WisdomTree Europe Hedged Equity Fund
# 26  iShares iBoxx USD High Yield Corporate Bond ETF
# 27                               iShares Gold Trust
# 28                 iShares NASDAQ Biotechnology ETF
# 29              iShares 7-10 Year Treasury Bond ETF
# ..                                              ...
# 37                        VanEck Vectors Russia ETF
# 38         ProShares UltraShort Bloomberg Crude Oil
# 39                      ProShares UltraShort S&P500
# 40               iShares 1-3 Year Treasury Bond ETF
# 41                             iShares Silver Trust
# 42                 VanEck Vectors Semiconductor ETF
# 43                           SPDR S&P 500 ETF Trust
# 44                          ProShares Ultra S&P 500
# 45           ProShares UltraShort 20+ Year Treasury
# 46               iShares 20+ Year Treasury Bond ETF
# 47                           ProShares UltraPro QQQ
# 48              ProShares Ultra Bloomberg Crude Oil
# 49                United States Natural Gas Fund LP
# 50                        ProShares UltraPro S&P500
# 51                        United States Oil Fund LP
# 52        Invesco DB U.S. Dollar Index Bullish Fund
# 53                             SPDR S&P BIOTECH ETF
# 54                        SPDR S&P Homebuilders ETF
# 55                Materials Select Sector SPDR Fund
# 56                   Energy Select Sector SPDR Fund
# 57                Financial Select Sector SPDR Fund
# 58               Industrial Select Sector SPDR Fund
# 59               Technology Select Sector SPDR Fund
# 60         Consumer Staples Select Sector SPDR Fund
# 61                Utilities Select Sector SPDR Fund
# 62              Health Care Select Sector SPDR Fund
# 63   Consumer Discretionary Select Sector SPDR Fund
# 64                     SPDR S&P Metals & Mining ETF
# 65  SPDR S&P Oil & Gas Exploration & Production ETF
# 66                              SPDR S&P Retail ETF
#
#                             issuer expense_ratio       aum spread  \
# 0                         JPMorgan         0.85%    $3.45B  0.04%
# 1                             ALPS         0.85%   $10.64B  0.10%
# 2                    Deutsche Bank         0.65%  $630.14M  0.04%
# 3     State Street Global Advisors         0.17%   $21.70B  0.01%
# 4                         Direxion         1.08%  $122.21M  0.06%
# 5                       WisdomTree         0.48%    $5.87B  0.02%
# 6                        BlackRock         0.69%   $31.82B  0.02%
# 7                        BlackRock         0.32%   $72.12B  0.01%
# 8                       WisdomTree         0.84%    $1.57B  0.04%
# 9                        BlackRock         0.49%    $3.44B  0.03%
# 10                       BlackRock         0.49%  $452.61M  0.03%
# 11                       BlackRock         0.49%   $17.39B  0.02%
# 12                       BlackRock         0.49%    $2.06B  0.03%
# 13                       BlackRock         0.49%    $1.26B  0.02%
# 14                       BlackRock         0.62%    $3.84B  0.02%
# 15                       BlackRock         0.62%    $6.88B  0.03%
# 16    State Street Global Advisors         0.29%    $3.56B  0.03%
# 17                             NaN           NaN       NaN    NaN
# 18                         Invesco         0.40%  $250.31M  0.01%
# 19                       BlackRock         0.74%    $4.05B  0.02%
# 20                         Invesco         0.40%  $125.03M  0.02%
# 21                          VanEck         0.53%    $8.82B  0.05%
# 22                          VanEck         0.54%    $4.90B  0.03%
# 23    State Street Global Advisors         0.40%   $30.57B  0.01%
# 24  Mirae Asset Global Investments         0.59%  $388.17M  0.11%
# 25                      WisdomTree         0.58%    $5.55B  0.02%
# 26                       BlackRock         0.49%   $16.35B  0.01%
# 27                       BlackRock         0.25%   $10.18B  0.08%
# 28                       BlackRock         0.47%    $9.28B  0.03%
# 29                       BlackRock         0.15%    $9.10B  0.01%
# ..                             ...           ...       ...    ...
# 37                          VanEck         0.67%    $1.66B  0.05%
# 38                       ProShares         1.25%  $168.01M  0.06%
# 39                       ProShares         0.89%  $842.62M  0.03%
# 40                       BlackRock         0.15%   $13.30B  0.01%
# 41                       BlackRock         0.50%    $5.04B  0.07%
# 42                          VanEck         0.35%    $1.30B  0.01%
# 43    State Street Global Advisors         0.09%  $275.42B  0.00%
# 44                       ProShares         0.90%    $2.59B  0.02%
# 45                       ProShares         0.90%    $1.76B  0.03%
# 46                       BlackRock         0.15%    $7.67B  0.01%
# 47                       ProShares         0.95%    $3.73B  0.02%
# 48                       ProShares         1.27%  $411.81M  0.04%
# 49              US Commodity Funds         1.29%  $331.18M  0.04%
# 50                       ProShares         0.95%    $1.47B  0.03%
# 51              US Commodity Funds         0.84%    $1.76B  0.07%
# 52                         Invesco         0.79%  $507.86M  0.04%
# 53    State Street Global Advisors         0.35%    $5.40B  0.03%
# 54    State Street Global Advisors         0.35%  $892.25M  0.03%
# 55    State Street Global Advisors         0.13%    $4.70B  0.02%
# 56    State Street Global Advisors         0.13%   $18.64B  0.01%
# 57    State Street Global Advisors         0.13%   $32.71B  0.04%
# 58    State Street Global Advisors         0.13%   $13.00B  0.01%
# 59    State Street Global Advisors         0.13%   $23.08B  0.01%
# 60    State Street Global Advisors         0.13%    $9.15B  0.02%
# 61    State Street Global Advisors         0.13%    $7.81B  0.02%
# 62    State Street Global Advisors         0.13%   $17.49B  0.01%
# 63    State Street Global Advisors         0.13%   $14.35B  0.01%
# 64    State Street Global Advisors         0.35%  $879.10M  0.03%
# 65    State Street Global Advisors         0.35%    $3.06B  0.02%
# 66    State Street Global Advisors         0.35%  $704.67M  0.02%
#
#                                               segment
# 0                                   Equity: U.S. MLPs
# 1                                   Equity: U.S. MLPs
# 2                        Equity: China - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                  Inverse Equity: Global Gold Miners
# 5                        Equity: Japan - Total Market
# 6             Equity: Emerging Markets - Total Market
# 7    Equity: Developed Markets Ex-U.S. - Total Market
# 8                        Equity: India - Total Market
# 9                      Equity: Germany - Total Market
# 10                       Equity: Italy - Total Market
# 11                       Equity: Japan - Total Market
# 12                        Equity: U.K. - Total Market
# 13                      Equity: Mexico - Total Market
# 14                 Equity: South Korea - Total Market
# 15                      Equity: Brazil - Total Market
# 16               Equity: Developed Europe - Large Cap
# 17                                                NaN
# 18                                     Currency: Euro
# 19                          Equity: China - Large Cap
# 20                             Currency: Japanese Yen
# 21                         Equity: Global Gold Miners
# 22                         Equity: Global Gold Miners
# 23                  Commodities: Precious Metals Gold
# 24                      Equity: Greece - Total Market
# 25            Equity: Developed Europe - Total Market
# 26          Fixed Income: U.S. - Corporate High Yield
# 27                  Commodities: Precious Metals Gold
# 28                               Equity: U.S. Biotech
# 29  Fixed Income: U.S. Government Treasury Interme...
# ..                                                ...
# 37                      Equity: Russia - Total Market
# 38              Inverse Commodities: Energy Crude Oil
# 39                   Inverse Equity: U.S. - Large Cap
# 40  Fixed Income: U.S. Government Treasury Short-Term
# 41                Commodities: Precious Metals Silver
# 42                      Equity: Global Semiconductors
# 43                           Equity: U.S. - Large Cap
# 44                 Leveraged Equity: U.S. - Large Cap
# 45  Inverse Fixed Income: U.S. Government Treasury...
# 46   Fixed Income: U.S. Government Treasury Long-Term
# 47                 Leveraged Equity: U.S. - Large Cap
# 48            Leveraged Commodities: Energy Crude Oil
# 49                    Commodities: Energy Natural Gas
# 50                 Leveraged Equity: U.S. - Large Cap
# 51                      Commodities: Energy Crude Oil
# 52            Inverse Currency: Basket - Global Ex-US
# 53                               Equity: U.S. Biotech
# 54                          Equity: U.S. Homebuilding
# 55                       Equity: U.S. Basic Materials
# 56                                Equity: U.S. Energy
# 57                            Equity: U.S. Financials
# 58                           Equity: U.S. Industrials
# 59                            Equity: U.S. Technology
# 60                Equity: U.S. Consumer Non-cyclicals
# 61                             Equity: U.S. Utilities
# 62                           Equity: U.S. Health Care
# 63                    Equity: U.S. Consumer Cyclicals
# 64                       Equity: U.S. Metals & Mining
# 65    Equity: U.S. Oil & Gas Exploration & Production
# 66                                Equity: U.S. Retail
#
# [67 rows x 9 columns]

# %% [markdown]
# Observations:
#
# 1. Notice that ticker FTK has `NaNs` for all the columns from `df_etf`.  That's because it doesn't exist in `df_etf`.

# %% [markdown]
# **Research Challenge:** Google `FTK` and figure out why it's not in `df_etf`.

# %% [markdown]
# **Coding Challenge:** Use `DataFrame` masking to grab the row of `df_joined` that consists of a non-match.  Hint: the method `pd.isna()` takes as an argument an array, it returns a `True` in for all the entries that are `NaN`, and returns `False` otherwise.

# %% [markdown]
# Let's clean up our result so it's exactly the information that we wanted in the first place: `df_weekly` with the `segment` column added to it.

# %%
# keeping only the columns that we want
# assigning the joined result to a variable called df_joined  
df_joined = \
    pd.merge(df_weekly, df_etf, how='left', left_on='ticker', right_on='symbol')\
    [['ticker', 'name_x', 'segment']]

# renaming the 'name' column
df_joined.rename(columns={'name_x':'name'}, inplace=True)

# let's look at our result
df_joined.head()
# Out:
#   ticker                                             name  \
# 0    AMJ                  JP Morgan Alerian MLP Index ETN
# 1   AMLP                                  Alerian MLP ETF
# 2   ASHR     Xtrackers Harvest CSI 300 China A-Shares ETF
# 3    DIA                  SPDR Dow Jones Ind Av ETF Trust
# 4   DUST  Direxion Daily Gold Miners Index Bear 3X Shares
#
#                               segment
# 0                   Equity: U.S. MLPs
# 1                   Equity: U.S. MLPs
# 2        Equity: China - Total Market
# 3            Equity: U.S. - Large Cap
# 4  Inverse Equity: Global Gold Miners

# %% [markdown]
# **Coding Challenge:** create the same `df_joined` as above, but instead use a `right-join` instead of a `left-join.`

# %% [markdown]
# ## Related Reading
#
# *PDSH* - 3.7 - Combining Datasets: Merging and Joining
